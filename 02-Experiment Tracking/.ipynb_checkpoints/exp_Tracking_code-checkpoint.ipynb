# %% [markdown]
# # Experimant Tracking Runs from Here

# %%
import pickle
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
mlflow.set_experiment('MLOPs-DTC_NY')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/3', creation_time=1719013007663, experiment_id='3', last_update_time=1719013007663, lifecycle_stage='active', name='MLOPs-DTC_NY', tags={}>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * we need pyarrow to workout with parquet
# * pip install pyarrow

# %%
data = pd.read_parquet('green_tripdata_2021-01.parquet')

# %%
data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0          5.5    0.5      0.5        0.00           0.0      None
# 1         10.0    0.5      0.5        2.81           0.0      None
# 2          6.0    0.5      0.5        1.00           0.0      None
# 3          8.0    0.5      0.5        0.00           0.0      None
# 4        -52.0    0.0     -0.5        0.00           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          6.80           2.0        1.0
# 1                    0.3         16.86           1.0        1.0
# 2                    0.3          8.30           1.0        1.0
# 3                    0.3          9.30           2.0        1.0
# 4                   -0.3        -52.80           3.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  2.75
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.5.0'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               76518 non-null  int64
#  1   lpep_pickup_datetime   76518 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  76518 non-null  datetime64[us]
#  3   store_and_fwd_flag     40471 non-null  object
#  4   RatecodeID             40471 non-null  float64
#  5   PULocationID           76518 non-null  int64
#  6   DOLocationID           76518 non-null  int64
#  7   passenger_count        40471 non-null  float64
#  8   trip_distance          76518 non-null  float64
#  9   fare_amount            76518 non-null  float64
#  10  extra                  76518 non-null  float64
#  11  mta_tax                76518 non-null  float64
#  12  tip_amount             76518 non-null  float64
#  13  tolls_amount           76518 non-null  float64
#  14  ehail_fee              0 non-null      object
#  15  improvement_surcharge  76518 non-null  float64
#  16  total_amount           76518 non-null  float64
#  17  payment_type           40471 non-null  float64
#  18  trip_type              40471 non-null  float64
#  19  congestion_surcharge   40471 non-null  float64
# dtypes: datetime64[us](2), float64(13), int64(3), object(2)
# memory usage: 11.7+ MB

# %%
data_train = pd.read_parquet('green_tripdata_2021-01.parquet')
data_val = pd.read_parquet('green_tripdata_2021-02.parquet')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               76518 non-null  int64
#  1   lpep_pickup_datetime   76518 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  76518 non-null  datetime64[us]
#  3   store_and_fwd_flag     40471 non-null  object
#  4   RatecodeID             40471 non-null  float64
#  5   PULocationID           76518 non-null  int64
#  6   DOLocationID           76518 non-null  int64
#  7   passenger_count        40471 non-null  float64
#  8   trip_distance          76518 non-null  float64
#  9   fare_amount            76518 non-null  float64
#  10  extra                  76518 non-null  float64
#  11  mta_tax                76518 non-null  float64
#  12  tip_amount             76518 non-null  float64
#  13  tolls_amount           76518 non-null  float64
#  14  ehail_fee              0 non-null      object
#  15  improvement_surcharge  76518 non-null  float64
#  16  total_amount           76518 non-null  float64
#  17  payment_type           40471 non-null  float64
#  18  trip_type              40471 non-null  float64
#  19  congestion_surcharge   40471 non-null  float64
# dtypes: datetime64[us](2), float64(13), int64(3), object(2)
# memory usage: 11.7+ MB

# %%
data.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
#### Text Manipulation for reading Flexibility

# %%
data_train['lpep_dropoff_datetime'] = pd.to_datetime(data_train['lpep_dropoff_datetime'])
data_train['lpep_pickup_datetime'] = pd.to_datetime(data_train['lpep_pickup_datetime'])

data_val['lpep_dropoff_datetime'] = pd.to_datetime(data_val['lpep_dropoff_datetime'])
data_val['lpep_pickup_datetime'] = pd.to_datetime(data_val['lpep_pickup_datetime'])

# %%
data_train['duration'] = data_train['lpep_dropoff_datetime'] - data_train['lpep_pickup_datetime']

data_val['duration'] = data_val['lpep_dropoff_datetime'] - data_val['lpep_pickup_datetime']

# %%
data_train['duration']
# Out:
# 0       0 days 00:03:56
# 1       0 days 00:08:45
# 2       0 days 00:05:58
# 3       0 days 00:07:05
# 4       0 days 00:00:04
#               ...
# 76513   0 days 00:38:00
# 76514   0 days 00:38:00
# 76515   0 days 00:11:00
# 76516   0 days 00:27:00
# 76517   0 days 00:10:00
# Name: duration, Length: 76518, dtype: timedelta64[us]

# %%
data_train['duration'] = data_train['duration'].apply(lambda x:x.total_seconds()/60)

data_val['duration'] = data_val['duration'].apply(lambda x:x.total_seconds()/60)

# %%
data_train = data_train[(data_train['duration'] >= 1) & (data_train['duration'] <= 60)]

data_val = data_val[(data_val['duration'] >= 1) & (data_val['duration'] <= 60)]

# %%
cat = ['PULocationID' , 'DOLocationID']
num = ['trip_distance']

# %%
data_train[cat] = data_train[cat].astype(str)

data_val[cat] = data_val[cat].astype(str)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73908 entries, 0 to 76517
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               73908 non-null  int64
#  1   lpep_pickup_datetime   73908 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  73908 non-null  datetime64[us]
#  3   store_and_fwd_flag     38175 non-null  object
#  4   RatecodeID             38175 non-null  float64
#  5   PULocationID           73908 non-null  object
#  6   DOLocationID           73908 non-null  object
#  7   passenger_count        38175 non-null  float64
#  8   trip_distance          73908 non-null  float64
#  9   fare_amount            73908 non-null  float64
#  10  extra                  73908 non-null  float64
#  11  mta_tax                73908 non-null  float64
#  12  tip_amount             73908 non-null  float64
#  13  tolls_amount           73908 non-null  float64
#  14  ehail_fee              0 non-null      object
#  15  improvement_surcharge  73908 non-null  float64
#  16  total_amount           73908 non-null  float64
#  17  payment_type           38175 non-null  float64
#  18  trip_type              38175 non-null  float64
#  19  congestion_surcharge   38175 non-null  float64
#  20  duration               73908 non-null  float64
# dtypes: datetime64[us](2), float64(14), int64(1), object(4)
# memory usage: 12.4+ MB

# %%
data_val
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-02-01 00:34:03   2021-02-01 00:51:58                  N
# 1             2  2021-02-01 00:04:00   2021-02-01 00:10:30                  N
# 2             2  2021-02-01 00:18:51   2021-02-01 00:34:06                  N
# 3             2  2021-02-01 00:53:27   2021-02-01 01:11:41                  N
# 4             2  2021-02-01 00:57:46   2021-02-01 01:06:44                  N
# ...         ...                  ...                   ...                ...
# 64567         2  2021-02-28 22:19:00   2021-02-28 22:29:00               None
# 64568         2  2021-02-28 23:18:00   2021-02-28 23:27:00               None
# 64569         2  2021-02-28 23:44:00   2021-02-28 23:58:00               None
# 64570         2  2021-02-28 23:07:00   2021-02-28 23:14:00               None
# 64571         2  2021-02-28 23:43:00   2021-02-28 23:50:00               None
#
#        RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0             1.0          130          205              5.0           3.66
# 1             1.0          152          244              1.0           1.10
# 2             1.0          152           48              1.0           4.93
# 3             1.0          152          241              1.0           6.70
# 4             1.0           75           42              1.0           1.89
# ...           ...          ...          ...              ...            ...
# 64567         NaN          129            7              NaN           2.63
# 64568         NaN          116          166              NaN           1.87
# 64569         NaN           74          151              NaN           2.40
# 64570         NaN           42           42              NaN           1.11
# 64571         NaN           42           41              NaN           1.40
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0            14.00  ...      0.5       10.00           0.0       None
# 1             6.50  ...      0.5        0.00           0.0       None
# 2            16.50  ...      0.5        0.00           0.0       None
# 3            21.00  ...      0.5        0.00           0.0       None
# 4             8.50  ...      0.5        2.45           0.0       None
# ...            ...  ...      ...         ...           ...        ...
# 64567        10.04  ...      0.0        0.00           0.0       None
# 64568         8.33  ...      0.0        1.89           0.0       None
# 64569        12.61  ...      0.0        0.00           0.0       None
# 64570        11.95  ...      0.0        0.00           0.0       None
# 64571         8.21  ...      0.0        0.00           0.0       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3         25.30           1.0        1.0
# 1                       0.3          7.80           2.0        1.0
# 2                       0.3         20.55           2.0        1.0
# 3                       0.3         22.30           2.0        1.0
# 4                       0.3         12.25           1.0        1.0
# ...                     ...           ...           ...        ...
# 64567                   0.3         10.34           NaN        NaN
# 64568                   0.3         10.52           NaN        NaN
# 64569                   0.3         12.91           NaN        NaN
# 64570                   0.3         15.00           NaN        NaN
# 64571                   0.3          8.51           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00  17.916667
# 1                      0.00   6.500000
# 2                      2.75  15.250000
# 3                      0.00  18.233333
# 4                      0.00   8.966667
# ...                     ...        ...
# 64567                   NaN  10.000000
# 64568                   NaN   9.000000
# 64569                   NaN  14.000000
# 64570                   NaN   7.000000
# 64571                   NaN   7.000000
#
# [61921 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               76518 non-null  int64
#  1   lpep_pickup_datetime   76518 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  76518 non-null  datetime64[us]
#  3   store_and_fwd_flag     40471 non-null  object
#  4   RatecodeID             40471 non-null  float64
#  5   PULocationID           76518 non-null  int64
#  6   DOLocationID           76518 non-null  int64
#  7   passenger_count        40471 non-null  float64
#  8   trip_distance          76518 non-null  float64
#  9   fare_amount            76518 non-null  float64
#  10  extra                  76518 non-null  float64
#  11  mta_tax                76518 non-null  float64
#  12  tip_amount             76518 non-null  float64
#  13  tolls_amount           76518 non-null  float64
#  14  ehail_fee              0 non-null      object
#  15  improvement_surcharge  76518 non-null  float64
#  16  total_amount           76518 non-null  float64
#  17  payment_type           40471 non-null  float64
#  18  trip_type              40471 non-null  float64
#  19  congestion_surcharge   40471 non-null  float64
# dtypes: datetime64[us](2), float64(13), int64(3), object(2)
# memory usage: 11.7+ MB

# %%
data_train = data_train[data_train['trip_type'] == 2]

data_val = data_val[data_val['trip_type'] == 2]

# %%
data_train['lpep_pickup_datetime'] = pd.to_datetime(data_train['lpep_pickup_datetime'])
data_train['lpep_dropoff_datetime'] = pd.to_datetime(data_train['lpep_dropoff_datetime'])

data_val['lpep_pickup_datetime'] = pd.to_datetime(data_val['lpep_pickup_datetime'])
data_val['lpep_dropoff_datetime'] = pd.to_datetime(data_val['lpep_dropoff_datetime'])
# Out:
# /tmp/ipykernel_5369/625001632.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val['lpep_pickup_datetime'] = pd.to_datetime(data_val['lpep_pickup_datetime'])
# /tmp/ipykernel_5369/625001632.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val['lpep_dropoff_datetime'] = pd.to_datetime(data_val['lpep_dropoff_datetime'])

# %%
data_train.head()
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 30         2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 53         2  2021-01-01 01:54:51   2021-01-01 02:15:35                  N
# 69         2  2021-01-01 02:42:49   2021-01-01 02:50:59                  N
# 88         2  2021-01-01 04:52:02   2021-01-01 05:05:01                  N
# 96         2  2021-01-01 05:52:43   2021-01-01 05:58:02                  N
#
#     RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 30         5.0           74          247              1.0           3.64
# 53         5.0           74           94              1.0           5.82
# 69         5.0          136          241              1.0           0.57
# 88         5.0          247           75              1.0           3.43
# 96         5.0            7            7              1.0           0.65
#
#     fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 30         13.0  ...      0.0         0.0           0.0       None
# 53         18.0  ...      0.0         0.0           0.0       None
# 69          9.0  ...      0.0         0.0           0.0       None
# 88         15.0  ...      0.0         0.0           0.0       None
# 96         50.0  ...      0.0         7.0           0.0       None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 30                   0.3          13.3           2.0        2.0
# 53                   0.3          18.3           2.0        2.0
# 69                   0.3           9.3           2.0        2.0
# 88                   0.3          15.3           2.0        2.0
# 96                   0.3          57.3           1.0        2.0
#
#     congestion_surcharge   duration
# 30                   0.0  19.766667
# 53                   0.0  20.733333
# 69                   0.0   8.166667
# 88                   0.0  12.983333
# 96                   0.0   5.316667
#
# [5 rows x 21 columns]

# %%
data_val.head()
# Out:
#      VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 5           2  2021-02-01 00:33:03   2021-02-01 00:40:54                  N
# 9           2  2021-02-01 02:56:55   2021-02-01 02:58:38                  N
# 114         2  2021-02-01 19:01:09   2021-02-01 19:11:20                  N
# 125         2  2021-02-01 22:57:12   2021-02-01 23:07:36                  N
# 150         2  2021-02-02 06:31:38   2021-02-02 06:50:10                  N
#
#      RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 5           5.0          197          219              1.0           3.30
# 9           5.0           78           78              1.0           0.00
# 114         5.0           75           74              1.0           1.80
# 125         5.0          223           92              1.0           4.98
# 150         5.0          223          100              1.0           5.64
#
#      fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 5           15.0  ...      0.0        0.76           0.0       None
# 9           24.0  ...      0.0        0.00           0.0       None
# 114         15.0  ...      0.0        0.00           0.0       None
# 125         50.0  ...      0.0        0.00           0.0       None
# 150         50.0  ...      0.0       13.26           0.0       None
#
#     improvement_surcharge  total_amount  payment_type  trip_type  \
# 5                     0.3         16.06           1.0        2.0
# 9                     0.3         24.30           2.0        2.0
# 114                   0.3         15.30           1.0        2.0
# 125                   0.3         50.30           2.0        2.0
# 150                   0.3         66.31           1.0        2.0
#
#      congestion_surcharge   duration
# 5                    0.00   7.850000
# 9                    0.00   1.716667
# 114                  0.00  10.183333
# 125                  0.00  10.400000
# 150                  2.75  18.533333
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Module : 1 -- Model Training

# %%
data_train['PU-DO'] = data_train['PULocationID'] + '-' + data_train['DOLocationID']

data_val['PU-DO'] = data_val['PULocationID'] + '-' + data_val['DOLocationID']
# Out:
# /tmp/ipykernel_5369/721656174.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val['PU-DO'] = data_val['PULocationID'] + '-' + data_val['DOLocationID']

# %%
catg = ['PU-DO']
nume = ['trip_distance']

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer()

# %%
train_dict = data_train[catg +  nume].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = data_val[catg +  nume].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
target = 'duration'

# %%
Y_train = data_train[target].values
Y_val = data_val[target].values

# %% [markdown]
# #### Wroking of Dict Vectorizer

# %%
from sklearn.feature_extraction import DictVectorizer

# Example data: list of dictionaries where each dictionary represents a sample
data = [
    {'city': 'New York', 'temperature': 32},
    {'city': 'San Francisco', 'temperature': 21},
    {'city': 'Chicago', 'temperature': 14},
    {'city': 'Boston', 'temperature': 29}
]

# Create an instance of DictVectorizer
vectorizer = DictVectorizer(sparse=False)  # sparse=False makes output dense, not sparse matrix

# Fit and transform the data with DictVectorizer
X = vectorizer.fit_transform(data)

# Print the feature names derived from the dictionaries
print("Feature names:", vectorizer.get_feature_names_out())

# Print the transformed data (numerical feature matrix)
print("Transformed data:\n", X)
# Out:
# Feature names: ['city=Boston' 'city=Chicago' 'city=New York' 'city=San Francisco'
#  'temperature']
# Transformed data:
#  [[ 0.  0.  1.  0. 32.]
#  [ 0.  0.  0.  1. 21.]
#  [ 0.  1.  0.  0. 14.]
#  [ 1.  0.  0.  0. 29.]]

# %% [markdown]
# #### Label Encoder Function

# %%
from sklearn.preprocessing import LabelEncoder

# Example data: categorical labels
labels = ['apple', 'banana', 'cherry', 'apple', 'banana']

# Create an instance of LabelEncoder
encoder = LabelEncoder()

# Fit and transform the labels
encoded_labels = encoder.fit_transform(labels)

# Print the encoded labels
print("Encoded labels:", encoded_labels)

# Reverse transformation (if needed)
decoded_labels = encoder.inverse_transform(encoded_labels)
print("Decoded labels:", decoded_labels)
# Out:
# Encoded labels: [0 1 2 0 1]
# Decoded labels: ['apple' 'banana' 'cherry' 'apple' 'banana']

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

# %%
lr = LinearRegression()
ridg = Ridge()
lass = Lasso()

# %%
lr.fit(X_train , Y_train)
ridg.fit(X_train , Y_train)
lass.fit(X_train , Y_train)
# Out:
# Lasso()

# %%
Y_pred_lr = lr.predict(X_val)
Y_pred_ridg = ridg.predict(X_val)
Y_pred_lass = lass.predict(X_val)

# %%
print('Linear Regression MSE : ' , mean_squared_error(Y_val , Y_pred_lr , squared=False))
print('Ridge Regression MSE : ' , mean_squared_error(Y_val , Y_pred_ridg , squared=False))
print('Lasso Regression MSE : ' , mean_squared_error(Y_val , Y_pred_lass , squared=False))
# Out:
# Linear Regression MSE :  8.353710401133316
# Ridge Regression MSE :  8.181513722504025
# Lasso Regression MSE :  8.672902008635951
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# #### Ridge and Lasso with lr

# %%
ridg_lr = Ridge(alpha= 0.00101)
lass_lr = Lasso(alpha=0.00101)

# %%
ridg_lr.fit(X_train , Y_train)
lass_lr.fit(X_train , Y_train)
# Out:
# Lasso(alpha=0.00101)

# %%
Y_pred_ridg_lr = ridg.predict(X_val)
Y_pred_lass_lr = lass.predict(X_val)

# %%
print('Ridge Regression with lr = 0.01 MSE : ' , mean_squared_error(Y_val , Y_pred_ridg_lr , squared=False))
print('Lasso Regression with lr = 0.01 MSE : ' , mean_squared_error(Y_val , Y_pred_lass_lr , squared=False))
# Out:
# Ridge Regression with lr = 0.01 MSE :  8.181513722504025
# Lasso Regression with lr = 0.01 MSE :  8.672902008635951
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# #### MSE Values

# %% [markdown]
# * Linear Regression MSE :  8.353710401133316
# * Ridge Regression MSE :  8.181513722504025
# * Lasso Regression MSE :  8.672902008635951
#
# **with Alpha = 0.01**
#
# * Ridge Regression with lr = 0.01 MSE :  8.181513722504025
# * Lasso Regression with lr = 0.01 MSE :  8.672902008635951

# %% [markdown]
# **USing ML Flow**

# %%
with mlflow.start_run():

    alpha = 0.001
    mlflow.log_param('alpha',alpha)

    mlflow.log_param('Train-data-path' , './green_tripdata_2021-01.parquet')
    mlflow.log_param('Test-data-path' , './green_tripdata_2021-02.parquet')

    mlflow.set_tag('Developer' , 'Vasanth')

    lr = LinearRegression()
    ridg_alpha = Ridge(alpha)
    lass_alpha = Lasso(alpha)

    lr.fit(X_train , Y_train)
    ridg_alpha.fit(X_train , Y_train)
    lass_alpha.fit(X_train , Y_train)

    Y_pred_lr = lr.predict(X_val)
    Y_pred_ridg = lr.predict(X_val)
    Y_pred_lass = lr.predict(X_val)

    rmse_lr = mean_squared_error(Y_val , Y_pred_lr , squared=False)
    rmse_ridg = mean_squared_error(Y_val , Y_pred_ridg , squared=False)
    rmse_lass = mean_squared_error(Y_val , Y_pred_lass , squared=False)

    mlflow.log_metric('rmse_lr' , rmse_lr)
    mlflow.log_metric('rmse_ridg' , rmse_ridg)
    mlflow.log_metric('rmse_lass' , rmse_lass)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ### Adding hyper parameters

# %%
# !pip install xgboost
# !pip install hyperopt
# Out:
# Requirement already satisfied: xgboost in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from xgboost) (2.22.3)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from xgboost) (1.13.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting hyperopt
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /home/codespace/.local/lib/python3.10/site-packages (from hyperopt) (3.3)
# Collecting future (from hyperopt)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting tqdm (from hyperopt)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.4 MB/s eta 0:00:004.8 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle in /usr/local/python/3.10.13/lib/python3.10/site-packages (from hyperopt) (3.0.0)
# Collecting py4j (from hyperopt)
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: py4j, tqdm, future, hyperopt
# Successfully installed future-1.0.0 hyperopt-0.2.7 py4j-0.10.9.7 tqdm-4.66.4
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=Y_train)
valid = xgb.DMatrix(X_val, label=Y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,#(epochs)
            evals=[(valid, 'validation')],
            early_stopping_rounds=50#(if for 50 test , rmse value is not changing then stop)
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(Y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:10.82962
# [1]	validation-rmse:10.25339
# [2]	validation-rmse:9.78403
# [3]	validation-rmse:9.40476
# [4]	validation-rmse:9.10899
# [5]	validation-rmse:8.86723
# [6]	validation-rmse:8.65547
# [7]	validation-rmse:8.50180
# [8]	validation-rmse:8.37441
# [9]	validation-rmse:8.27314
# [10]	validation-rmse:8.18174
# [11]	validation-rmse:8.11848
# [12]	validation-rmse:8.06356
# [13]	validation-rmse:8.03223
# [14]	validation-rmse:8.00250
# [15]	validation-rmse:7.97700
# [16]	validation-rmse:7.95721
# [17]	validation-rmse:7.94273
# [18]	validation-rmse:7.93725
# [19]	validation-rmse:7.92648
# [20]	validation-rmse:7.90675
# [21]	validation-rmse:7.89336
# [22]	validation-rmse:7.87269
# [23]	validation-rmse:7.86729
# [24]	validation-rmse:7.86024
# [25]	validation-rmse:7.85419
# [26]	validation-rmse:7.85053
# [27]	validation-rmse:7.84762
# [28]	validation-rmse:7.84794
# [29]	validation-rmse:7.84540
# [30]	validation-rmse:7.84936
# [31]	validation-rmse:7.86156
# [32]	validation-rmse:7.85786
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:56:31] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [33]	validation-rmse:7.85639
# [34]	validation-rmse:7.85797
# [35]	validation-rmse:7.86293
# [36]	validation-rmse:7.86888
# [37]	validation-rmse:7.87449
# [38]	validation-rmse:7.87869
# [39]	validation-rmse:7.88493
# [40]	validation-rmse:7.88979
# [41]	validation-rmse:7.89117
# [42]	validation-rmse:7.88938
# [43]	validation-rmse:7.89284
# [44]	validation-rmse:7.90013
# [45]	validation-rmse:7.90226
# [46]	validation-rmse:7.90725
# [47]	validation-rmse:7.91159
# [48]	validation-rmse:7.91724
# [49]	validation-rmse:7.91991
# [50]	validation-rmse:7.91991
# [51]	validation-rmse:7.91715
# [52]	validation-rmse:7.91739
# [53]	validation-rmse:7.91748
# [54]	validation-rmse:7.92634
# [55]	validation-rmse:7.92757
# [56]	validation-rmse:7.92175
# [57]	validation-rmse:7.93040
# [58]	validation-rmse:7.92931
# [59]	validation-rmse:7.93368
# [60]	validation-rmse:7.93076
# [61]	validation-rmse:7.93576
# [62]	validation-rmse:7.93836
# [63]	validation-rmse:7.93484
# [64]	validation-rmse:7.93769
# [65]	validation-rmse:7.94480
# [66]	validation-rmse:7.94832
# [67]	validation-rmse:7.95052
# [68]	validation-rmse:7.94696
# [69]	validation-rmse:7.94686
# [70]	validation-rmse:7.95137
# [71]	validation-rmse:7.95495
# [72]	validation-rmse:7.96237
# [73]	validation-rmse:7.95576
# [74]	validation-rmse:7.96014
# [75]	validation-rmse:7.96194
# [76]	validation-rmse:7.96216
# [77]	validation-rmse:7.96347
# [78]	validation-rmse:7.96952
# [0]	validation-rmse:10.93446
# [1]	validation-rmse:10.41924
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:56:31] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:9.99836
# [3]	validation-rmse:9.64600
# [4]	validation-rmse:9.35324
# [5]	validation-rmse:9.11199
# [6]	validation-rmse:8.90379
# [7]	validation-rmse:8.73126
# [8]	validation-rmse:8.58740
# [9]	validation-rmse:8.47166
# [10]	validation-rmse:8.36843
# [11]	validation-rmse:8.29081
# [12]	validation-rmse:8.22278
# [13]	validation-rmse:8.18166
# [14]	validation-rmse:8.13363
# [15]	validation-rmse:8.09750
# [16]	validation-rmse:8.07616
# [17]	validation-rmse:8.05911
# [18]	validation-rmse:8.04357
# [19]	validation-rmse:8.03413
# [20]	validation-rmse:8.02913
# [21]	validation-rmse:8.02642
# [22]	validation-rmse:8.02181
# [23]	validation-rmse:8.01615
# [24]	validation-rmse:8.01932
# [25]	validation-rmse:8.01556
# [26]	validation-rmse:8.01465
# [27]	validation-rmse:8.01025
# [28]	validation-rmse:8.01152
# [29]	validation-rmse:8.01243
# [30]	validation-rmse:8.01425
# [31]	validation-rmse:8.01232
# [32]	validation-rmse:8.01182
# [33]	validation-rmse:8.00423
# [34]	validation-rmse:7.99556
# [35]	validation-rmse:7.99186
# [36]	validation-rmse:7.98551
# [37]	validation-rmse:7.98809
# [38]	validation-rmse:7.99166
# [39]	validation-rmse:7.99465
# [40]	validation-rmse:7.99417
# [41]	validation-rmse:7.99735
# [42]	validation-rmse:8.00063
# [43]	validation-rmse:8.00166
# [44]	validation-rmse:8.00176
# [45]	validation-rmse:8.00410
# [46]	validation-rmse:8.00615
# [47]	validation-rmse:8.01423
# [48]	validation-rmse:8.01486
# [49]	validation-rmse:8.01688
# [50]	validation-rmse:8.01945
# [51]	validation-rmse:8.01970
# [52]	validation-rmse:8.02630
# [53]	validation-rmse:8.02657
# [54]	validation-rmse:8.02367
# [55]	validation-rmse:8.01831
# [56]	validation-rmse:8.01911
# [57]	validation-rmse:8.02182
# [58]	validation-rmse:8.02367
# [59]	validation-rmse:8.02896
# [60]	validation-rmse:8.02998
# [61]	validation-rmse:8.02760
# [62]	validation-rmse:8.02330
# [63]	validation-rmse:8.02513
# [64]	validation-rmse:8.02659
# [65]	validation-rmse:8.03153
# [66]	validation-rmse:8.02750
# [67]	validation-rmse:8.02813
# [68]	validation-rmse:8.03037
# [69]	validation-rmse:8.03422
# [70]	validation-rmse:8.03382
# [71]	validation-rmse:8.03002
# [72]	validation-rmse:8.03130
# [73]	validation-rmse:8.03084
# [74]	validation-rmse:8.03286
# [75]	validation-rmse:8.03594
# [76]	validation-rmse:8.04096
# [77]	validation-rmse:8.04378
# [78]	validation-rmse:8.04129
# [79]	validation-rmse:8.04267
# [80]	validation-rmse:8.04096
# [81]	validation-rmse:8.04123
# [82]	validation-rmse:8.04663
# [83]	validation-rmse:8.05287
# [84]	validation-rmse:8.05152
# [85]	validation-rmse:8.05179
# [86]	validation-rmse:8.05180
# [0]	validation-rmse:9.08084
# [1]	validation-rmse:8.32863
# [2]	validation-rmse:8.04799
# [3]	validation-rmse:8.01843
# [4]	validation-rmse:8.03027
# [5]	validation-rmse:8.03867
#   4%|██                                                  | 2/50 [00:01<00:34,  1.38trial/s, best loss: 7.966810278194685]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:56:32] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [6]	validation-rmse:7.97869
# [7]	validation-rmse:7.97213
# [8]	validation-rmse:8.01126
# [9]	validation-rmse:8.01754
# [10]	validation-rmse:8.05505
# [11]	validation-rmse:8.02185
# [12]	validation-rmse:8.02431
# [13]	validation-rmse:8.05825
# [14]	validation-rmse:8.07731
# [15]	validation-rmse:8.08596
# [16]	validation-rmse:8.05053
# [17]	validation-rmse:8.08100
# [18]	validation-rmse:8.09620
# [19]	validation-rmse:8.12577
# [20]	validation-rmse:8.12684
# [21]	validation-rmse:8.12165
# [22]	validation-rmse:8.15924
# [23]	validation-rmse:8.15420
# [24]	validation-rmse:8.17317
# [25]	validation-rmse:8.16992
# [26]	validation-rmse:8.17281
# [27]	validation-rmse:8.18979
# [28]	validation-rmse:8.20250
# [29]	validation-rmse:8.20988
# [30]	validation-rmse:8.21931
# [31]	validation-rmse:8.21891
# [32]	validation-rmse:8.22604
# [33]	validation-rmse:8.23783
# [34]	validation-rmse:8.25988
# [35]	validation-rmse:8.25503
# [36]	validation-rmse:8.25373
# [37]	validation-rmse:8.26748
# [38]	validation-rmse:8.26664
# [39]	validation-rmse:8.28492
# [40]	validation-rmse:8.27967
# [41]	validation-rmse:8.27988
# [42]	validation-rmse:8.28853
# [43]	validation-rmse:8.29560
# [44]	validation-rmse:8.29168
# [45]	validation-rmse:8.29882
# [46]	validation-rmse:8.30378
# [47]	validation-rmse:8.30040
# [48]	validation-rmse:8.30252
# [49]	validation-rmse:8.31552
# [50]	validation-rmse:8.31846
# [51]	validation-rmse:8.32512
# [52]	validation-rmse:8.34025
# [53]	validation-rmse:8.33750
# [54]	validation-rmse:8.35227
# [55]	validation-rmse:8.34476
# [56]	validation-rmse:8.34587
# [57]	validation-rmse:8.34576
# [0]	validation-rmse:11.21890
# [1]	validation-rmse:10.92419
# [2]	validation-rmse:10.65351
# [3]	validation-rmse:10.40095
# [4]	validation-rmse:10.18070
# [5]	validation-rmse:9.97882
#   6%|███                                                 | 3/50 [00:02<00:33,  1.41trial/s, best loss: 7.966810278194685]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:56:33] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [6]	validation-rmse:9.79292
# [7]	validation-rmse:9.62268
# [8]	validation-rmse:9.46881
# [9]	validation-rmse:9.32517
# [10]	validation-rmse:9.19304
# [11]	validation-rmse:9.07818
# [12]	validation-rmse:8.96364
# [13]	validation-rmse:8.86152
# [14]	validation-rmse:8.77005
# [15]	validation-rmse:8.68551
# [16]	validation-rmse:8.61175
# [17]	validation-rmse:8.54431
# [18]	validation-rmse:8.48749
# [19]	validation-rmse:8.43098
# [20]	validation-rmse:8.38113
# [21]	validation-rmse:8.33548
# [22]	validation-rmse:8.29510
# [23]	validation-rmse:8.25933
# [24]	validation-rmse:8.23102
# [25]	validation-rmse:8.20290
# [26]	validation-rmse:8.17343
# [27]	validation-rmse:8.15053
# [28]	validation-rmse:8.13335
# [29]	validation-rmse:8.11107
# [30]	validation-rmse:8.09815
# [31]	validation-rmse:8.08015
# [32]	validation-rmse:8.06433
# [33]	validation-rmse:8.05571
# [34]	validation-rmse:8.04390
# [35]	validation-rmse:8.03057
# [36]	validation-rmse:8.01893
# [37]	validation-rmse:8.01187
# [38]	validation-rmse:8.00323
# [39]	validation-rmse:8.00194
# [40]	validation-rmse:7.99591
# [41]	validation-rmse:7.99628
# [42]	validation-rmse:7.99498
# [43]	validation-rmse:7.99465
# [44]	validation-rmse:7.99080
# [45]	validation-rmse:7.99041
# [46]	validation-rmse:7.98896
# [47]	validation-rmse:7.98792
# [48]	validation-rmse:7.98154
# [49]	validation-rmse:7.98264
# [50]	validation-rmse:7.98165
# [51]	validation-rmse:7.98330
# [52]	validation-rmse:7.98024
# [53]	validation-rmse:7.98370
# [54]	validation-rmse:7.98356
# [55]	validation-rmse:7.98134
# [56]	validation-rmse:7.98266
# [57]	validation-rmse:7.98475
# [58]	validation-rmse:7.98944
# [59]	validation-rmse:7.98797
# [60]	validation-rmse:7.99086
# [61]	validation-rmse:7.99405
# [62]	validation-rmse:7.99415
# [63]	validation-rmse:7.99283
# [64]	validation-rmse:7.99423
# [65]	validation-rmse:7.99518
# [66]	validation-rmse:7.99337
# [67]	validation-rmse:7.99182
# [68]	validation-rmse:7.99009
# [69]	validation-rmse:7.98933
# [70]	validation-rmse:7.98779
# [71]	validation-rmse:7.98674
# [72]	validation-rmse:7.98554
# [73]	validation-rmse:7.98372
# [74]	validation-rmse:7.98473
# [75]	validation-rmse:7.98431
# [76]	validation-rmse:7.98720
# [77]	validation-rmse:7.98515
# [78]	validation-rmse:7.98728
# [79]	validation-rmse:7.98687
# [80]	validation-rmse:7.98958
# [81]	validation-rmse:7.98931
# [82]	validation-rmse:7.99284
# [83]	validation-rmse:7.99388
# [84]	validation-rmse:7.99540
# [85]	validation-rmse:7.99558
# [86]	validation-rmse:7.99801
# [87]	validation-rmse:7.99955
# [88]	validation-rmse:8.00063
# [89]	validation-rmse:8.00292
# [90]	validation-rmse:8.00230
# [91]	validation-rmse:8.00662
# [92]	validation-rmse:8.01068
# [93]	validation-rmse:8.00694
# [94]	validation-rmse:8.00922
# [95]	validation-rmse:8.01113
# [96]	validation-rmse:8.00985
# [97]	validation-rmse:8.01034
# [98]	validation-rmse:8.01194
# [99]	validation-rmse:8.01128
# [100]	validation-rmse:8.01158
# [101]	validation-rmse:8.01553
# [102]	validation-rmse:8.01717
# [0]	validation-rmse:8.24084
# [1]	validation-rmse:8.05457
#   8%|████▏                                               | 4/50 [00:03<00:37,  1.22trial/s, best loss: 7.966810278194685]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:56:34] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:7.96158
# [3]	validation-rmse:7.98046
# [4]	validation-rmse:7.99983
# [5]	validation-rmse:8.04131
# [6]	validation-rmse:8.04399
# [7]	validation-rmse:8.07469
# [8]	validation-rmse:8.05467
# [9]	validation-rmse:8.08289
# [10]	validation-rmse:8.05672
# [11]	validation-rmse:8.08467
# [12]	validation-rmse:8.09342
# [13]	validation-rmse:8.09916
# [14]	validation-rmse:8.14303
# [15]	validation-rmse:8.13954
# [16]	validation-rmse:8.11757
# [17]	validation-rmse:8.13439
# [18]	validation-rmse:8.11034
# [19]	validation-rmse:8.14375
# [20]	validation-rmse:8.15428
# [21]	validation-rmse:8.16280
# [22]	validation-rmse:8.17488
# [23]	validation-rmse:8.17593
# [24]	validation-rmse:8.18248
# [25]	validation-rmse:8.18855
# [26]	validation-rmse:8.18386
# [27]	validation-rmse:8.19854
# [28]	validation-rmse:8.21566
# [29]	validation-rmse:8.23038
# [30]	validation-rmse:8.23227
# [31]	validation-rmse:8.23656
# [32]	validation-rmse:8.25120
# [33]	validation-rmse:8.24215
# [34]	validation-rmse:8.25995
# [35]	validation-rmse:8.27267
# [36]	validation-rmse:8.26673
# [37]	validation-rmse:8.26158
# [38]	validation-rmse:8.27721
# [39]	validation-rmse:8.27028
# [40]	validation-rmse:8.29692
# [41]	validation-rmse:8.28670
# [42]	validation-rmse:8.29890
# [43]	validation-rmse:8.29649
# [44]	validation-rmse:8.29914
# [45]	validation-rmse:8.29678
# [46]	validation-rmse:8.30789
# ...
# [11]	validation-rmse:8.12125
# [12]	validation-rmse:8.12881
# [13]	validation-rmse:8.16524
# [14]	validation-rmse:8.16456
# [15]	validation-rmse:8.18401
# [16]	validation-rmse:8.18482
# [17]	validation-rmse:8.17724
# [18]	validation-rmse:8.19863
# [19]	validation-rmse:8.20070
# [20]	validation-rmse:8.20321
# [21]	validation-rmse:8.23142
# [22]	validation-rmse:8.23930
# [23]	validation-rmse:8.24621
# [24]	validation-rmse:8.25646
# [25]	validation-rmse:8.24751
# [26]	validation-rmse:8.26395
# [27]	validation-rmse:8.26810
# [28]	validation-rmse:8.27799
# [29]	validation-rmse:8.29044
# [30]	validation-rmse:8.30173
# [31]	validation-rmse:8.31320
# [32]	validation-rmse:8.31199
# [33]	validation-rmse:8.32114
# [34]	validation-rmse:8.32385
# [35]	validation-rmse:8.32552
# [36]	validation-rmse:8.32924
# [37]	validation-rmse:8.33264
# [38]	validation-rmse:8.33972
# [39]	validation-rmse:8.35323
# [40]	validation-rmse:8.35941
# [41]	validation-rmse:8.36117
# [42]	validation-rmse:8.36927
# [43]	validation-rmse:8.37194
# [44]	validation-rmse:8.37427
# [45]	validation-rmse:8.38214
# [46]	validation-rmse:8.38444
# [47]	validation-rmse:8.38629
# [48]	validation-rmse:8.39545
# [49]	validation-rmse:8.40451
# [50]	validation-rmse:8.40739
# [51]	validation-rmse:8.40578
# [52]	validation-rmse:8.40925
# [53]	validation-rmse:8.41485
# [54]	validation-rmse:8.41827
# [55]	validation-rmse:8.42177
# [56]	validation-rmse:8.42299
# [57]	validation-rmse:8.43225
# [58]	validation-rmse:8.43361
# [59]	validation-rmse:8.43677
# [0]	validation-rmse:8.83343
# [1]	validation-rmse:8.40432
# [2]	validation-rmse:8.16881
# [3]	validation-rmse:8.12232
#  98%|█████████████████████████████████████████████████▉ | 49/50 [00:40<00:00,  1.20trial/s, best loss: 7.734059319416033]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [23:57:11] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [4]	validation-rmse:8.15677
# [5]	validation-rmse:8.12441
# [6]	validation-rmse:8.12257
# [7]	validation-rmse:8.12550
# [8]	validation-rmse:8.12595
# [9]	validation-rmse:8.12370
# [10]	validation-rmse:8.12218
# [11]	validation-rmse:8.12185
# [12]	validation-rmse:8.10859
# [13]	validation-rmse:8.10481
# [14]	validation-rmse:8.10654
# [15]	validation-rmse:8.09923
# [16]	validation-rmse:8.10445
# [17]	validation-rmse:8.10099
# [18]	validation-rmse:8.10253
# [19]	validation-rmse:8.10007
# [20]	validation-rmse:8.10178
# [21]	validation-rmse:8.09965
# [22]	validation-rmse:8.09692
# [23]	validation-rmse:8.09788
# [24]	validation-rmse:8.09830
# [25]	validation-rmse:8.10135
# [26]	validation-rmse:8.10178
# [27]	validation-rmse:8.09956
# [28]	validation-rmse:8.10151
# [29]	validation-rmse:8.09961
# [30]	validation-rmse:8.10217
# [31]	validation-rmse:8.10411
# [32]	validation-rmse:8.10430
# [33]	validation-rmse:8.10424
# [34]	validation-rmse:8.10355
# [35]	validation-rmse:8.10446
# [36]	validation-rmse:8.10335
# [37]	validation-rmse:8.10473
# [38]	validation-rmse:8.10439
# [39]	validation-rmse:8.10361
# [40]	validation-rmse:8.10430
# [41]	validation-rmse:8.10429
# [42]	validation-rmse:8.10316
# [43]	validation-rmse:8.10257
# [44]	validation-rmse:8.10427
# [45]	validation-rmse:8.10457
# [46]	validation-rmse:8.10396
# [47]	validation-rmse:8.10541
# [48]	validation-rmse:8.10633
# [49]	validation-rmse:8.10659
# [50]	validation-rmse:8.10699
# [51]	validation-rmse:8.10678
# [52]	validation-rmse:8.10671
# [53]	validation-rmse:8.10719
# [54]	validation-rmse:8.10673
# [55]	validation-rmse:8.10678
# [56]	validation-rmse:8.10659
# [57]	validation-rmse:8.10687
# [58]	validation-rmse:8.10648
# [59]	validation-rmse:8.10724
# [60]	validation-rmse:8.10630
# [61]	validation-rmse:8.10640
# [62]	validation-rmse:8.10651
# [63]	validation-rmse:8.10662
# [64]	validation-rmse:8.10777
# [65]	validation-rmse:8.10738
# [66]	validation-rmse:8.10794
# [67]	validation-rmse:8.10768
# [68]	validation-rmse:8.10757
# [69]	validation-rmse:8.10856
# [70]	validation-rmse:8.10844
# [71]	validation-rmse:8.10898
# [72]	validation-rmse:8.10801
# 100%|███████████████████████████████████████████████████| 50/50 [00:40<00:00,  1.23trial/s, best loss: 7.734059319416033]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ### Selection model with less rmse as main model

# %% [markdown]
# Saving the model and also auto logging

# %%
params = {
    'learning_rate' : 0.559722359178164,
    'max_depth' : 21,
    'min_child_weight' : 0.6471590075305966,
    'objective' : 'reg:linear',
    'reg_alpha' : 0.02525710944995532,
    'reg_lambda' : 0.07252400608721207,
    'seed' : 42
}

'''with mlflow.start_run():

    mlflow.set_tag()

    mlflow.log_param()'''

## For auto Logging

mlflow.xgboost.autolog()

booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,#(epochs)
            evals=[(valid, 'validation')],
            early_stopping_rounds=50#(if for 50 test , rmse value is not changing then stop)
        )
# Out:
# 2024/06/22 00:22:06 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# 2024/06/22 00:22:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1ac3863cd0c0499e8db0ea3f96c796d8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:8.83343
# /usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [00:22:06] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:8.40432
# [2]	validation-rmse:8.16881
# [3]	validation-rmse:8.12232
# [4]	validation-rmse:8.15677
# [5]	validation-rmse:8.12441
# [6]	validation-rmse:8.12257
# [7]	validation-rmse:8.12550
# [8]	validation-rmse:8.12595
# [9]	validation-rmse:8.12370
# [10]	validation-rmse:8.12218
# [11]	validation-rmse:8.12185
# [12]	validation-rmse:8.10859
# [13]	validation-rmse:8.10481
# [14]	validation-rmse:8.10654
# [15]	validation-rmse:8.09923
# [16]	validation-rmse:8.10445
# [17]	validation-rmse:8.10099
# [18]	validation-rmse:8.10253
# [19]	validation-rmse:8.10007
# [20]	validation-rmse:8.10178
# [21]	validation-rmse:8.09965
# [22]	validation-rmse:8.09692
# [23]	validation-rmse:8.09788
# [24]	validation-rmse:8.09830
# [25]	validation-rmse:8.10135
# [26]	validation-rmse:8.10178
# [27]	validation-rmse:8.09956
# [28]	validation-rmse:8.10151
# [29]	validation-rmse:8.09961
# [30]	validation-rmse:8.10217
# [31]	validation-rmse:8.10411
# [32]	validation-rmse:8.10430
# [33]	validation-rmse:8.10424
# [34]	validation-rmse:8.10355
# [35]	validation-rmse:8.10446
# [36]	validation-rmse:8.10335
# [37]	validation-rmse:8.10473
# [38]	validation-rmse:8.10439
# [39]	validation-rmse:8.10361
# [40]	validation-rmse:8.10430
# [41]	validation-rmse:8.10429
# [42]	validation-rmse:8.10316
# [43]	validation-rmse:8.10257
# [44]	validation-rmse:8.10427
# [45]	validation-rmse:8.10457
# [46]	validation-rmse:8.10396
# [47]	validation-rmse:8.10541
# [48]	validation-rmse:8.10633
# [49]	validation-rmse:8.10659
# [50]	validation-rmse:8.10699
# [51]	validation-rmse:8.10678
# [52]	validation-rmse:8.10671
# [53]	validation-rmse:8.10719
# [54]	validation-rmse:8.10673
# [55]	validation-rmse:8.10678
# [56]	validation-rmse:8.10659
# [57]	validation-rmse:8.10687
# [58]	validation-rmse:8.10648
# [59]	validation-rmse:8.10724
# [60]	validation-rmse:8.10630
# [61]	validation-rmse:8.10640
# [62]	validation-rmse:8.10651
# [63]	validation-rmse:8.10662
# [64]	validation-rmse:8.10777
# [65]	validation-rmse:8.10738
# [66]	validation-rmse:8.10794
# [67]	validation-rmse:8.10768
# [68]	validation-rmse:8.10757
# [69]	validation-rmse:8.10856
# [70]	validation-rmse:8.10844
# [71]	validation-rmse:8.10898
# 2024/06/22 00:22:09 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/06/22 00:22:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/usr/local/python/3.10.13/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [00:22:09] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
